# %%
import main
import matplotlib.pyplot as plt
import random
import torch

# """
# here we can visualize some data using matplotlib
# """


# declare the main.py variables

device = main.device

model = main.model

optimizer = main.optimizer

loss_fn = main.loss_fn

loaders = main.loaders

dataset_dict = main.dict_of_datas

# %%
"""
lets pass some values from the validation set and check the results

"""


num_of_pics = 10
list_of_random_ints = random.sample(range(1, len(dataset_dict['validation_dataset'])), num_of_pics)

# loading the model
main.load_model(torch.load("model_checkpoints//saved_model.pth.ptr", map_location=torch.device('cpu')))

for index in list_of_random_ints:
    main.test_one_value(index)
# Out:
# >>> Model loaded
# C:\Users\miki2\Programowanie\Solvro_rekr_2023_zima\solvro-rekrutacja-zimowa-backup\src\model_CNN.py:97: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
